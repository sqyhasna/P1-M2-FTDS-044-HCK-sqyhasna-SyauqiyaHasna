# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open('P1M2_Syauqiya_Hasna_model.pkl', 'rb') as file: 
    model = pickle.load(file)
model
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['application_order',
#                                                    'previous_qualification_grade',
#                                                    'admission_grade',
#                                                    'age_at_enrollment',
#                                                    'curricular_units_1st_sem_credited',
#                                                    'curricular_units_1st_sem_enrolled',
# ...

# %% [markdown]
# disini model yang sebelumnya sudah disimpan dalam bentuk .pkl dipanggil lagi menggunakan pickle. jadi model tidak perlu ditraining ulang dan bisa langsung digunakan untuk melakukan prediction pada data baru

# %%
data_inf = {
    'marital_status': [1],
    'application_mode': [17],
    'application_order': [2],
    'course': [9254],
    'daytime_evening_attendance': [1],
    'previous_qualification': [1],
    'previous_qualification_grade': [150],
    'nationality': [1],
    'mothers_qualification': [19],
    'fathers_qualification': [12],
    'mothers_occupation': [5],
    'fathers_occupation': [9],
    'admission_grade': [145],
    'displaced': [1],
    'educational_special_needs': [0],
    'debtor': [0],
    'tuition_fees_up_to_date': [1],
    'gender': [0],
    'scholarship_holder': [1],
    'age_at_enrollment': [20],
    'international': [0],
    'curricular_units_1st_sem_credited': [0],
    'curricular_units_1st_sem_enrolled': [6],
    'curricular_units_1st_sem_evaluations': [6],
    'curricular_units_1st_sem_approved': [6],
    'curricular_units_1st_sem_grade': [13],
    'curricular_units_1st_sem_without_evaluations': [0],
    'curricular_units_2nd_sem_credited': [0],
    'curricular_units_2nd_sem_enrolled': [6],
    'curricular_units_2nd_sem_evaluations': [6],
    'curricular_units_2nd_sem_approved': [5],
    'curricular_units_2nd_sem_grade': [13],
    'curricular_units_2nd_sem_without_evaluations': [0],
    'unemployment_rate': [11],
    'inflation_rate': [0.6],
    'gdp': [2.0]
}

df_inf = pd.DataFrame(data_inf)
df_inf
# Out:
#    marital_status  application_mode  application_order  course  \
# 0               1                17                  2    9254
#
#    daytime_evening_attendance  previous_qualification  \
# 0                           1                       1
#
#    previous_qualification_grade  nationality  mothers_qualification  \
# 0                           150            1                     19
#
#    fathers_qualification  ...  curricular_units_1st_sem_without_evaluations  \
# 0                     12  ...                                             0
#
#    curricular_units_2nd_sem_credited  curricular_units_2nd_sem_enrolled  \
# 0                                  0                                  6
#
#    curricular_units_2nd_sem_evaluations  curricular_units_2nd_sem_approved  \
# 0                                     6                                  5
#
#    curricular_units_2nd_sem_grade  \
# 0                              13
#
# ...

# %% [markdown]
# data inference dibuat sebanyak 1 data student dengan feature yang sama seperti data yang digunakan saat training. data ini nantinya digunakan untuk melihat hasil prediction dari model terhadap student baru

# %% [markdown]
# ## Model Prediction

# %%
pred_inf = model.predict(df_inf)

# %% [markdown]
# model kemudian melakukan prediction pada "df_inf". hasil prediction masih berupa angka sesuai dengan encoding target yang digunakan sebelumnya
